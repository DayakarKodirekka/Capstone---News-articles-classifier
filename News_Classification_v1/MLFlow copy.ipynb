# %%
import pandas as pd
import pyspark
import mlflow
import mlflow.spark

from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer
from pyspark.ml import Pipeline
from pyspark.ml.feature import RegexTokenizer, StopWordsRemover, CountVectorizer
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
import mlflow.mleap
from pyspark.ml.feature import HashingTF, IDF

# %%
# Entertainment
import requests
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"entertainment","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring, verify=False)

print(response.text)
# Out:
# C:\Users\KSindhu\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'free-news.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {"status":"ok","total_hits":6559,"page":1,"total_pages":263,"page_size":25,"articles":[{"title":"STARZPLAY debuts in the South Asian entertainment segment, inks deal with STAR TV network to feature six Indian entertainment channels","author":null,"published_date":"2021-10-27 15:48:00","published_date_precision":"full","link":"https://finance.yahoo.com/news/starzplay-debuts-south-asian-entertainment-154800025.html","clean_url":"yahoo.com","summary":"DUBAI, UAE, Oct. 27, 2021 /PRNewswire/ -- STARZPLAY, MENA region's leading SVOD service, has signed a deal with STAR TV network to feature six of their popular entertainment channels. With this deal, STARZPLAY will foray into the South Asian entertainment segment with plans to further expand this entertainment space.\n\nSTARZPLAY debuts in the South Asian entertainment segment, inks deal with STAR TV network to feature six Indian entertainment channels\n\nSTARZPLAY has introduced an all-new dedicated South Asian entertainment package that features Star Plus ME, Star Gold International, Jalsha Movies, Asianet Movies, Star Vijay International and Asianet ME channels.","rights":"yahoo.com","rank":30,"topic":"news","country":"US","language":"en","authors":[],"media":"https://s.yimg.com/uu/api/res/1.2/hQQeOyRUE30yG_pP8fJGyA--~B/aD00MDA7dz03MTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/prnewswire.com/67aea4c76fc800eb59a8814030ae7a2c","is_opinion":false,"twitter_account":"@Yahoo","_score":9.975083,"_id":"4ec93bdf7c2c1bb3b6f7d18405820c2b"},{"title":"Hall of Fame Resort & Entertainment Company Announces Release Date for Third Quarter 2021 Results","author":null,"published_date":"2021-10-28 20:30:00","published_date_precision":"full","link":"https://www.businesswire.com/news/home/20211028006016/en/Hall-of-Fame-Resort-Entertainment-Company-Announces-Release-Date-for-Third-Quarter-2021-Results","clean_url":"businesswire.com","summary":"October 28, 2021 04:30 PM Eastern Daylight Time CANTON, Ohio--(BUSINESS WIRE)--Hall of Fame Resort & Entertainment Company (NASDAQ: HOFV, HOFVW), the only resort, entertainment and media company centered around the power of professional football, will release its third quarter fiscal 2021 results for the period ended September 30, 2021, on Wednesday, November 10, 2021, after the close of trading on Nasdaq.\n\nThe Company will host a conference call on Thursday, November 11, 2021, at 8:30 a.m. ET, to provide commentary on the business.","rights":"Copyright 2021, Business Wire.","rank":297,"topic":"news","country":"unknown","language":"en","authors":[],"media":"https://mms.businesswire.com/media/20211028006016/en/824202/23/HOFV_Logo.jpg","is_opinion":false,"twitter_account":"@businesswire","_score":9.947628,"_id":"d77e73c7a36aedc71e07802c9feaa83d"},{"title":"Caesars Rewards Celebrated as Gaming's Best Loyalty Program","author":null,"published_date":"2021-10-29 21:42:00","published_date_precision":"full","link":"https://finance.yahoo.com/news/caesars-rewards-celebrated-gamings-best-214200945.html","clean_url":"yahoo.com","summary":"Caesars Rewards named \"Best Players Club\" in USA TODAY 10Best Readers' Choice Awards, and \"Customer Loyalty Program of the Year\" at the Global Gaming Awards\n\nLAS VEGAS and RENO, Nev., Oct. 29, 2021 /PRNewswire/ -- Caesars Entertainment, Inc. (NASDAQ: CZR) continues to lead the gaming industry in customer loyalty as its legendary loyalty program, Caesars Rewards, is honored as the best of its kind by both gaming industry peers and Caesars Rewards members and guests.\n\n(PRNewsfoto/Caesars Entertainment Inc.","rights":"yahoo.com","rank":30,"topic":"news","country":"US","language":"en","authors":[],"media":"https://s.yimg.com/uu/api/res/1.2/zjTOuZL.Iq0iO7r9hGLP0w--~B/aD0yMjU7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/prnewswire.com/b5934d738a07e4f684f1a02ce1e830af","is_opinion":false,"twitter_account":"@Yahoo","_score":9.853536,"_id":"51a40405f6c7a8c0e05d329e28f0f081"},{"title":"Caesars Rewards Celebrated as Gaming's ...

# %%
import json
# entertaiment 
json_string = response.text
print(json_string)
print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
print(stud_obj)
print("The type of object is: ", type(stud_obj))

# %%
news_et = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_et.append(item_title)

# %%
import pandas as pd
df_e = pd.DataFrame(news_et,columns=['title','summary','link','pub_date','topic','author'])

# %% [markdown]
# # # Sports Category

# %%
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"sports","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)

# %%
# sports 
json_string = response.text
print(json_string)
print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
print(stud_obj)
print("The type of object is: ", type(stud_obj))

# %%
news_sp = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_sp.append(item_title)

# %%
df_sp = pd.DataFrame(news_sp,columns=['title','summary','link','pub_date','topic','author'])

# %% [markdown]
# #business

# %%
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"business","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)

# %%
json_string = response.text
print(json_string)
print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
print(stud_obj)
print("The type of object is: ", type(stud_obj))
# Out:
# {"status":"ok","total_hits":10000,"page":1,"total_pages":400,"page_size":25,"articles":[{"title":"Industry Titans, Grant Cardone and Partner, Brandon Dawson, Launch 10X Buy Sell to Create Value and Transform Business Brokerage for the Lower Middle Market","author":"Cardone Ventures","published_date":"2021-10-24 17:30:00","published_date_precision":"timezone unknown","link":"https://www.globenewswire.com/news-release/2021/10/24/2319463/0/en/Industry-Titans-Grant-Cardone-and-Partner-Brandon-Dawson-Launch-10X-Buy-Sell-to-Create-Value-and-Transform-Business-Brokerage-for-the-Lower-Middle-Market.html","clean_url":"globenewswire.com","summary":"MIAMI, Oct. 24, 2021 (GLOBE NEWSWIRE) -- Cardone Ventures, LLC announces the launch of a digital mergers and acquisitions platform, 10XBuySell.com, through its subsidiary, 10X Buy Sell LLC. This newly launched platform is specifically designed for successful entrepreneurs looking to exit their current venture(s), grow through an acquisition, or for individuals looking to start an entrepreneurial journey. The 10X Buy Sell platform is purpose-built to guide you through every step of the process. The newly launched platform builds upon the 10X team's proven success in providing growth and scaling strategies to business owners.","rights":"globenewswire.com","rank":610,"topic":"news","country":"unknown","language":"en","authors":["Cardone Ventures"],"media":"https://ml.globenewswire.com/media/MWRjNzE4NWEtODU4OS00OGQ5LWI1ZTAtMWRiMTFiZDNlYjZlLTEyMzU2OTU=/tiny/Cardone-Ventures.png","is_opinion":false,"twitter_account":"globenewswire","_score":6.307112,"_id":"3735b1e467af749ecf766b0788629e42"},{"title":"Can You Apply For A Small Business Credit Card With Only Your EIN?","author":"Chauncey Crail","published_date":"2021-10-26 13:00:59","published_date_precision":"full","link":"https://www.forbes.com/advisor/credit-cards/can-you-apply-for-a-small-business-credit-card-with-only-your-ein/","clean_url":"forbes.com","summary":"Editorial Note: Forbes Advisor may earn a commission on sales made from partner links on this page, but that doesn't affect our editors' opinions or evaluations.\n Using an Employer Identification Number (EIN) has benefits when applying for a business credit card. Business owners can keep personal and business finances separate and avoid negative activity from reflecting on a personal credit history. Small business owners, however, will likely have a hard time finding a small business credit card that accepts an EIN over a Social Security Number (SSN).","rights":"forbes.com","rank":51,"topic":"news","country":"US","language":"en","authors":["Chauncey Crail","Dia Adams","Contributor","Published","Oct"],"media":"https://www.forbes.com/advisor/wp-content/uploads/2021/10/Getty-1.jpg","is_opinion":false,"twitter_account":"@forbes","_score":6.2995524,"_id":"97470ef5ecd3ca36204ebefbd6c89443"},{"title":"SBA to Host National Veterans Small Business Week Nov. 1-5","author":"United States Small Business Administration","published_date":"2021-10-27 21:13:39","published_date_precision":"full","link":"https://apnews.com/press-release/globe-newswire/business-veterans-small-business-us-small-business-administration-dcfe91682a20dfea5a668e3c65985ca3","clean_url":"apnews.com","summary":"Washington, Oct. 27, 2021 (GLOBE NEWSWIRE) -- The\u00a0 U.S. Small Business Administration \u00a0will celebrate the entrepreneurial spirit and resilience of our veteran small business owners during National Veterans Small Business Week, Nov. 1-5, 2021.'National Veterans Small Business Week is a time to honor the service and celebrate the impact of our nearly 1.8 million veteran entrepreneurs who are a driving force in our economy, generating approximately $1 trillion annually and employing nearly 4 million people,' said SBA Administrator Isabella Casillas Guzman.","rights":"apnews.com","rank":377,"topic":"business","country":"US","language":"en","authors":["United States Small Business Administration"],"media":"https://ap ...
#
# The type of object is:  <class 'str'>
# {'status': 'ok', 'total_hits': 10000, 'page': 1, 'total_pages': 400, 'page_size': 25, 'articles': [{'title': 'Industry Titans, Grant Cardone and Partner, Brandon Dawson, Launch 10X Buy Sell to Create Value and Transform Business Brokerage for the Lower Middle Market', 'author': 'Cardone Ventures', 'published_date': '2021-10-24 17:30:00', 'published_date_precision': 'timezone unknown', 'link': 'https://www.globenewswire.com/news-release/2021/10/24/2319463/0/en/Industry-Titans-Grant-Cardone-and-Partner-Brandon-Dawson-Launch-10X-Buy-Sell-to-Create-Value-and-Transform-Business-Brokerage-for-the-Lower-Middle-Market.html', 'clean_url': 'globenewswire.com', 'summary': "MIAMI, Oct. 24, 2021 (GLOBE NEWSWIRE) -- Cardone Ventures, LLC announces the launch of a digital mergers and acquisitions platform, 10XBuySell.com, through its subsidiary, 10X Buy Sell LLC. This newly launched platform is specifically designed for successful entrepreneurs looking to exit their current venture(s), grow through an acquisition, or for individuals looking to start an entrepreneurial journey. The 10X Buy Sell platform is purpose-built to guide you through every step of the process. The newly launched platform builds upon the 10X team's proven success in providing growth and scaling strategies to business owners.", 'rights': 'globenewswire.com', 'rank': 610, 'topic': 'news', 'country': 'unknown', 'language': 'en', 'authors': ['Cardone Ventures'], 'media': 'https://ml.globenewswire.com/media/MWRjNzE4NWEtODU4OS00OGQ5LWI1ZTAtMWRiMTFiZDNlYjZlLTEyMzU2OTU=/tiny/Cardone-Ventures.png', 'is_opinion': False, 'twitter_account': 'globenewswire', '_score': 6.307112, '_id': '3735b1e467af749ecf766b0788629e42'}, {'title': 'Can You Apply For A Small Business Credit Card With Only Your EIN?', 'author': 'Chauncey Crail', 'published_date': '2021-10-26 13:00:59', 'published_date_precision': 'full', 'link': 'https://www.forbes.com/advisor/credit-cards/can-you-apply-for-a-small-business-credit-card-with-only-your-ein/', 'clean_url': 'forbes.com', 'summary': "Editorial Note: Forbes Advisor may earn a commission on sales made from partner links on this page, but that doesn't affect our editors' opinions or evaluations.\n Using an Employer Identification Number (EIN) has benefits when applying for a business credit card. Business owners can keep personal and business finances separate and avoid negative activity from reflecting on a personal credit history. Small business owners, however, will likely have a hard time finding a small business credit card that accepts an EIN over a Social Security Number (SSN).", 'rights': 'forbes.com', 'rank': 51, 'topic': 'news', 'country': 'US', 'language': 'en', 'authors': ['Chauncey Crail', 'Dia Adams', 'Contributor', 'Published', 'Oct'], 'media': 'https://www.forbes.com/advisor/wp-content/uploads/2021/10/Getty-1.jpg', 'is_opinion': False, 'twitter_account': '@forbes', '_score': 6.2995524, '_id': '97470ef5ecd3ca36204ebefbd6c89443'}, {'title': 'SBA to Host National Veterans Small Business Week Nov. 1-5', 'author': 'United States Small Business Administration', 'published_date': '2021-10-27 21:13:39', 'published_date_precision': 'full', 'link': 'https://apnews.com/press-release/globe-newswire/business-veterans-small-business-us-small-business-administration-dcfe91682a20dfea5a668e3c65985ca3', 'clean_url': 'apnews.com', 'summary': "Washington, Oct. 27, 2021 (GLOBE NEWSWIRE) -- The\xa0 U.S. Small Business Administration \xa0will celebrate the entrepreneurial spirit and resilience of our veteran small business owners during National Veterans Small Business Week, Nov. 1-5, 2021.'National Veterans Small Business Week is a time to honor the service and celebrate the impact of our nearly 1.8 million veteran entrepreneurs who are a driving force in our economy, generating approximately $1 trillion annually and employing nearly 4 million people,' said SBA Administrator Isabella Casillas Guzman.", 'rights': 'apnews.com', 'rank': 377, 'topic': 'business', 'coun ...
# The type of object is:  <class 'dict'>

# %%
news_bs = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_bs.append(item_title)
  # print(item['title'])

# %%
df_bs = pd.DataFrame(news_bs,columns=['title','summary','link','pub_date','topic','author'])

# %% [markdown]
# #tech

# %%
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"technology","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You have exceeded the rate limit per second for your plan, BASIC, by the API provider"}

# %%
json_string = response.text
print(json_string)
print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
print(stud_obj)
print("The type of object is: ", type(stud_obj))
# Out:
# {"message":"You have exceeded the rate limit per second for your plan, BASIC, by the API provider"}
# The type of object is:  <class 'str'>
# {'message': 'You have exceeded the rate limit per second for your plan, BASIC, by the API provider'}
# The type of object is:  <class 'dict'>

# %%
news_tech = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_tech.append(item_title)
  # print(item['title'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-408bc6eb039b> in <module>
#       1 news_tech = []
# ----> 2 for item in stud_obj['articles']:
#       3   item_title = {}
#       4   item_title['title'] = item['title']
#       5   item_title['link'] = item['link']
#
# KeyError: 'articles'

# %%
df_tech = pd.DataFrame(news_tech,columns=['title','summary','link','pub_date','topic','author'])

# %% [markdown]
# # Merging all dataframes

# %%
df_s1 = df_bs.append(df_sp, ignore_index=True)
df_s2 = df_s1.append(df_tech, ignore_index=True)
df_s3 = df_s2.append(df_e, ignore_index=True)
df_Final = df_s3.append(df_bs, ignore_index=True)

# %%
train_df = spark.createDataFrame(df_Final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-43bd8c59f582> in <module>
# ----> 1 train_df = spark.createDataFrame(df_Final)
#
# NameError: name 'spark' is not defined

# %% [markdown]
# # LogReg CrossValidation using hyperParameters

# %%
# Start a new MLflow run
import mlflow.mleap
import mlflow.sklearn
from pyspark.ml.feature import HashingTF, IDF
from pyspark.ml import Pipeline
from pyspark.ml.feature import RegexTokenizer, StopWordsRemover, CountVectorizer
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, IDF
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

with mlflow.start_run(run_name="News_priediction_cvModel") as run:
  
# regular expression tokenizer
  regexTokenizer = RegexTokenizer(inputCol="summary", outputCol="words", pattern="\\W")
  # stop words
  add_stopwords = ["http","https","amp","rt","t","c","the"] 
  stopwordsRemover = StopWordsRemover(inputCol="words", outputCol="filtered").setStopWords(add_stopwords)
  # bag of words count
  countVectors = CountVectorizer(inputCol="filtered", outputCol="features", vocabSize=10000, minDF=5)
  label_stringIdx = StringIndexer(inputCol = "topic", outputCol = "label")

  #Logestic Regression implementation

  lr = LogisticRegression(maxIter=20, regParam=0.3, elasticNetParam=0)
  pipeline = Pipeline(stages=[regexTokenizer, stopwordsRemover, countVectors, label_stringIdx,lr])
  pipelineFit = pipeline.fit(train_df)
  dataset = pipelineFit.transform(train_df)
  (trainingData, testData) = dataset.randomSplit([0.7, 0.3], seed = 100)
  
 
  evaluator_lr_tf = MulticlassClassificationEvaluator(predictionCol="prediction")
  # Create ParamGrid for Cross Validation
  paramGrid = (ParamGridBuilder()
              .addGrid(lr.regParam, [0.1, 0.3, 0.5]) # regularization parameter
              .addGrid(lr.elasticNetParam, [0.0, 0.1, 0.2]) # Elastic Net Parameter (Ridge = 0)
  #            .addGrid(model.maxIter, [10, 20, 50]) #Number of iterations
  #            .addGrid(idf.numFeatures, [10, 100, 1000]) # Number of features
              .build())
  # Create 5-fold CrossValidator
  cv = CrossValidator(estimator=pipeline, \
                      estimatorParamMaps=paramGrid, \
                      evaluator=evaluator_lr_tf, \
                      numFolds=5)
  cvModel = cv.fit(trainingData)

  predictions = cvModel.transform(testData)
  # Evaluate best model
  evaluator_cv = MulticlassClassificationEvaluator(predictionCol="prediction")
  evaluator_cv.evaluate(predictions)
  runID = run.info.run_uuid
  experimentID = run.info.experiment_id

  print("Inside MLflow Run with run_id {} and experiment_id {}".format(runID, experimentID))
  # mlflow.sklearn.log_model(lrModel, "lrModel")
  # mlflow.log_params(params)
  # Training data f1 score
  evaluator_cv = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol='label', metricName='f1')
  F1 = evaluator_cv.evaluate(predictions)
  # Training data Accuracy
  evaluator_cv = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol='label', metricName='accuracy')
  acc = evaluator_cv.evaluate(predictions)
  # print some data
  print("F1_score_Training",F1)
  print("Accuracy_Training",acc)

  mlflow.spark.log_model(spark_model=cvModel, sample_input=trainingData, artifact_path="model")
  mlflow.spark.save_model(cvModel, "cvModel")

# %%
import joblib
from joblib import dump

# dump the pipeline model
dump(pipeline, filename="text_classification.joblib")
