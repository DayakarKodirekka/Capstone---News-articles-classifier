# %%
import pandas as pd
import pyspark
import mlflow
import mlflow.spark

from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer
from pyspark.ml import Pipeline
from pyspark.ml.feature import RegexTokenizer, StopWordsRemover, CountVectorizer
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
import mlflow.mleap
from pyspark.ml.feature import HashingTF, IDF
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29132/4122111047.py in <module>
#       1 import pandas as pd
# ----> 2 import pyspark
#       3 import mlflow
#       4 import mlflow.spark
#       5
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
# Entertainment
import requests
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"entertainment","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;status&#34;:&#34;ok&#34;,&#34;total_hits&#34;:6630,&#34;page&#34;:1,&#34;total_pages&#34;:266,&#34;page_size&#34;:25,&#34;articles&#34;:[{&#34;title&#34;:&#34;Caesars Entertainment, Inc. Appoints Sandra Douglass Morgan to Board of Directors&#34;,&#34;author&#34;:null,&#34;published_date&#34;:&#34;2021-10-22 12:55:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://finance.yahoo.com/news/caesars-entertainment-inc-appoints-sandra-125500274.html&#34;,&#34;clean_url&#34;:&#34;yahoo.com&#34;,&#34;summary&#34;:&#34;LAS VEGAS and RENO, Nev., Oct. 22, 2021 /PRNewswire/ -- Caesars Entertainment, Inc. (NASDAQ: CZR) today announced the appointment of Sandra Douglass Morgan to its Board of Directors, effective November 7, 2021, and subject to required regulatory approvals. Morgan, an attorney, is the past chairwoman of the Nevada Gaming Control board and the first African American to serve as chair.\n\n(PRNewsfoto/Caesars Entertainment Inc.)\n\nCaesars Entertainment, Inc. today announced the appointment of Sandra Douglass Morgan to its Board of Directors.&#34;,&#34;rights&#34;:&#34;yahoo.com&#34;,&#34;rank&#34;:30,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[],&#34;media&#34;:&#34;https://s.yimg.com/uu/api/res/1.2/zjTOuZL.Iq0iO7r9hGLP0w--~B/aD0yMjU7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/prnewswire.com/b5934d738a07e4f684f1a02ce1e830af&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@Yahoo&#34;,&#34;_score&#34;:10.043935,&#34;_id&#34;:&#34;00c3aa04936dad8e17a9a6f4b8848d5a&#34;},{&#34;title&#34;:&#34;PDF Download!@ Entertainment Law: Fundamentals and Practice Read ^boo\u2026&#34;,&#34;author&#34;:&#34;Rayne543532525&#34;,&#34;published_date&#34;:&#34;2021-10-22 03:32:52&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.slideshare.net/Rayne543532525/pdf-download-entertainment-law-fundamentals-and-practice-read-book-epub&#34;,&#34;clean_url&#34;:&#34;slideshare.net&#34;,&#34;summary&#34;:&#34;1. WELCOME TO MY SLIDE DOWNLOAD OR READ BEST SELLER BOOK (PAGE 1)\nEntertainment Law: Fundamentals and Practice\n[PDF] Download Ebooks, Ebooks Download and Read Online, Read Onlline, Epub Ebook KINDLE, PDF Full eBook\nBEST SELLER IN 2019-2021\nCLICK NEXT PAGE 2. WELCOME TO MY SLIDE DOWNLOAD OR READ BEST SELLER BOOK (PAGE 2)\nEntertainment Law: Fundamentals and Practice\nBOOK REVIEW\nCLICK NEXT PAGE 3. WELCOME TO MY SLIDE DOWNLOAD OR READ BEST SELLER BOOK (PAGE 3)\nEntertainment Law: Fundamentals and Practice\nBOOK DESCRIPTION\nEntertainment Law: Fundamentals and Practice is a comprehensive and unique &#39;how to&#39; guide covering every\narea of entertainment law including fundamental principles, detailed business models, legal foundations, contract\nterms, practical advice, and full legal citations for cases and statutes.&#34;,&#34;rights&#34;:&#34;slideshare.net&#34;,&#34;rank&#34;:108,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;unknown&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Rayne543532525&#34;],&#34;media&#34;:&#34;https://cdn.slidesharecdn.com/ss_thumbnails/entertainmentlawfundamentalsandpractice-211022033252-thumbnail-4.jpg?cb=1634873580&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@slideshare&#34;,&#34;_score&#34;:10.01743,&#34;_id&#34;:&#34;2b4361c43d6ca50af6d99378ce245329&#34;},{&#34;title&#34;:&#34;Caesars Entertainment, Inc. Appoints Sandra Douglass Morgan to Board of Directors&#34;,&#34;author&#34;:&#34;Caesars Entertainment&#34;,&#34;published_date&#34;:&#34;2021-10-22 12:55:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.prnewswire.com/news-releases/caesars-entertainment-inc-appoints-sandra-douglass-morgan-to-board-of-directors-301406551.html&#34;,&#34;clean_url&#34;:&#34;prnewswire.com&#34;,&#34;summary&#34;:&#34;Caesars Entertainment, Inc. today announced ...

# %%
import json
# entertaiment 
json_string = response.text
print(json_string)
print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
print(stud_obj)
print("The type of object is: ", type(stud_obj))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;status&#34;:&#34;ok&#34;,&#34;total_hits&#34;:6630,&#34;page&#34;:1,&#34;total_pages&#34;:266,&#34;page_size&#34;:25,&#34;articles&#34;:[{&#34;title&#34;:&#34;Caesars Entertainment, Inc. Appoints Sandra Douglass Morgan to Board of Directors&#34;,&#34;author&#34;:null,&#34;published_date&#34;:&#34;2021-10-22 12:55:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://finance.yahoo.com/news/caesars-entertainment-inc-appoints-sandra-125500274.html&#34;,&#34;clean_url&#34;:&#34;yahoo.com&#34;,&#34;summary&#34;:&#34;LAS VEGAS and RENO, Nev., Oct. 22, 2021 /PRNewswire/ -- Caesars Entertainment, Inc. (NASDAQ: CZR) today announced the appointment of Sandra Douglass Morgan to its Board of Directors, effective November 7, 2021, and subject to required regulatory approvals. Morgan, an attorney, is the past chairwoman of the Nevada Gaming Control board and the first African American to serve as chair.\n\n(PRNewsfoto/Caesars Entertainment Inc.)\n\nCaesars Entertainment, Inc. today announced the appointment of Sandra Douglass Morgan to its Board of Directors.&#34;,&#34;rights&#34;:&#34;yahoo.com&#34;,&#34;rank&#34;:30,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[],&#34;media&#34;:&#34;https://s.yimg.com/uu/api/res/1.2/zjTOuZL.Iq0iO7r9hGLP0w--~B/aD0yMjU7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/prnewswire.com/b5934d738a07e4f684f1a02ce1e830af&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@Yahoo&#34;,&#34;_score&#34;:10.043935,&#34;_id&#34;:&#34;00c3aa04936dad8e17a9a6f4b8848d5a&#34;},{&#34;title&#34;:&#34;PDF Download!@ Entertainment Law: Fundamentals and Practice Read ^boo\u2026&#34;,&#34;author&#34;:&#34;Rayne543532525&#34;,&#34;published_date&#34;:&#34;2021-10-22 03:32:52&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.slideshare.net/Rayne543532525/pdf-download-entertainment-law-fundamentals-and-practice-read-book-epub&#34;,&#34;clean_url&#34;:&#34;slideshare.net&#34;,&#34;summary&#34;:&#34;1. WELCOME TO MY SLIDE DOWNLOAD OR READ BEST SELLER BOOK (PAGE 1)\nEntertainment Law: Fundamentals and Practice\n[PDF] Download Ebooks, Ebooks Download and Read Online, Read Onlline, Epub Ebook KINDLE, PDF Full eBook\nBEST SELLER IN 2019-2021\nCLICK NEXT PAGE 2. WELCOME TO MY SLIDE DOWNLOAD OR READ BEST SELLER BOOK (PAGE 2)\nEntertainment Law: Fundamentals and Practice\nBOOK REVIEW\nCLICK NEXT PAGE 3. WELCOME TO MY SLIDE DOWNLOAD OR READ BEST SELLER BOOK (PAGE 3)\nEntertainment Law: Fundamentals and Practice\nBOOK DESCRIPTION\nEntertainment Law: Fundamentals and Practice is a comprehensive and unique &#39;how to&#39; guide covering every\narea of entertainment law including fundamental principles, detailed business models, legal foundations, contract\nterms, practical advice, and full legal citations for cases and statutes.&#34;,&#34;rights&#34;:&#34;slideshare.net&#34;,&#34;rank&#34;:108,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;unknown&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Rayne543532525&#34;],&#34;media&#34;:&#34;https://cdn.slidesharecdn.com/ss_thumbnails/entertainmentlawfundamentalsandpractice-211022033252-thumbnail-4.jpg?cb=1634873580&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@slideshare&#34;,&#34;_score&#34;:10.01743,&#34;_id&#34;:&#34;2b4361c43d6ca50af6d99378ce245329&#34;},{&#34;title&#34;:&#34;Caesars Entertainment, Inc. Appoints Sandra Douglass Morgan to Board of Directors&#34;,&#34;author&#34;:&#34;Caesars Entertainment&#34;,&#34;published_date&#34;:&#34;2021-10-22 12:55:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.prnewswire.com/news-releases/caesars-entertainment-inc-appoints-sandra-douglass-morgan-to-board-of-directors-301406551.html&#34;,&#34;clean_url&#34;:&#34;prnewswire.com&#34;,&#34;summary&#34;:&#34;Caesars Entertainment, Inc. today announced ...

# %%
news_et = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_et.append(item_title)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd
df_e = pd.DataFrame(news_et,columns=['title','summary','link','pub_date','topic','author'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # # Sports Category

# %%
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"sports","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;status&#34;:&#34;ok&#34;,&#34;total_hits&#34;:9869,&#34;page&#34;:1,&#34;total_pages&#34;:395,&#34;page_size&#34;:25,&#34;articles&#34;:[{&#34;title&#34;:&#34;Seahawks&#39; full list of 2022 free agents&#34;,&#34;author&#34;:&#34;Tim Weaver&#34;,&#34;published_date&#34;:&#34;2021-10-24 07:37:18&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://seahawkswire.usatoday.com/lists/seahawks-full-list-of-2022-free-agents/&#34;,&#34;clean_url&#34;:&#34;usatoday.com&#34;,&#34;summary&#34;:&#34;The Seattle Seahawks will have some tough decisions to make this coming offseason, no matter how the rest of this year plays out. Their starting left tackle, free safety, tight end, right cornerback and No. 2 quarterback are all going to become free agents next March, just to name a few. (AP Photo/Elaine Thompson) Joe Nicholson-USA TODAY Sports Brad Rempel-USA TODAY Sports Charles LeClaire-USA TODAY Sports Joe Nicholson-USA TODAY Sports Darren Yamashita-USA TODAY Sports Joe Nicholson-USA TODAY Sports Rich Barnes-USA TODAY Sports Joe Nicholson-USA TODAY Sports Rich Barnes-USA TODAY Sports Joe Camporeale-USA TODAY Sports Trevor Ruszkowski-USA TODAY Sports Joe Nicholson-USA TODAY Sports Darren Yamashita-USA TODAY Sports Joe Nicholson-USA TODAY Sports (AP Photo/Ted S.&#34;,&#34;rights&#34;:&#34;usatoday.com&#34;,&#34;rank&#34;:126,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Tim Weaver&#34;,&#34;October&#34;,&#34;Am Pt&#34;],&#34;media&#34;:&#34;https://seahawkswire.usatoday.com/wp-content/uploads/sites/61/2019/07/usatsi_11420506.jpg?w=1024&amp;h=576&amp;crop=1&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:null,&#34;_score&#34;:9.579414,&#34;_id&#34;:&#34;367d956086ea77886f4727640df11ac8&#34;},{&#34;title&#34;:&#34;Seahawks&#39; full list of 2022 free agents&#34;,&#34;author&#34;:&#34;Tim Weaver&#34;,&#34;published_date&#34;:&#34;2021-10-24 14:37:18&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://sports.yahoo.com/seahawks-full-list-2022-free-143718044.html&#34;,&#34;clean_url&#34;:&#34;yahoo.com&#34;,&#34;summary&#34;:&#34;The Seattle Seahawks will have some tough decisions to make this coming offseason, no matter how the rest of this year plays out. Their starting left tackle, free safety, tight end, right cornerback and No. 2 quarterback are all going to become free agents next March, just to name a few.\n\nHere is the full list of Seattle&#39;s pending 2022 free agents.\n\nFS Quandre Diggs\n\n(AP Photo/Elaine Thompson)\n\nLT Duane Brown\n\nJoe Nicholson-USA TODAY Sports\n\nCB D.J. Reed\n\nBrad Rempel-USA TODAY Sports\n\nTE Gerald E&#34;,&#34;rights&#34;:&#34;yahoo.com&#34;,&#34;rank&#34;:30,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Tim Weaver&#34;],&#34;media&#34;:&#34;https://s.yimg.com/ny/api/res/1.2/MBPMeSQbPKpYGzFX3aiNaw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/uu/api/res/1.2/3s48MSRrpdotaFM2d0QkQw--~B/aD0xNzA3O3c9MjU2MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/seattle_seahawks_wire_usa_today_sports_articles_798/e0e0589ce7fb76386e83d88a6387917b&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@Yahoo&#34;,&#34;_score&#34;:9.522131,&#34;_id&#34;:&#34;6d8e5c85fe80b1272c3a795d2b99f1bc&#34;},{&#34;title&#34;:&#34;Global Spectator Sports Market Report 2021 Featuring FC Barcelona, Dallas Cowboys, Real Madrid, Manchester United, &amp; New York Yankees&#34;,&#34;author&#34;:&#34;Research&#34;,&#34;published_date&#34;:&#34;2021-10-20 00:00:00&#34;,&#34;published_date_precision&#34;:&#34;date&#34;,&#34;link&#34;:&#34;https://www.globenewswire.com/news-release/2021/10/20/2317073/28124/en/Global-Spectator-Sports-Market-Report-2021-Featuring-FC-Barcelona-Dallas-Cowboys-Real-Madrid-Manchester-United-New-York-Yankees.html&#34;,&#34;clean_url&#34;:&#34;globenewswire.c ...

# %%
# sports 
json_string = response.text
print(json_string)
print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
print(stud_obj)
print("The type of object is: ", type(stud_obj))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;status&#34;:&#34;ok&#34;,&#34;total_hits&#34;:9869,&#34;page&#34;:1,&#34;total_pages&#34;:395,&#34;page_size&#34;:25,&#34;articles&#34;:[{&#34;title&#34;:&#34;Seahawks&#39; full list of 2022 free agents&#34;,&#34;author&#34;:&#34;Tim Weaver&#34;,&#34;published_date&#34;:&#34;2021-10-24 07:37:18&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://seahawkswire.usatoday.com/lists/seahawks-full-list-of-2022-free-agents/&#34;,&#34;clean_url&#34;:&#34;usatoday.com&#34;,&#34;summary&#34;:&#34;The Seattle Seahawks will have some tough decisions to make this coming offseason, no matter how the rest of this year plays out. Their starting left tackle, free safety, tight end, right cornerback and No. 2 quarterback are all going to become free agents next March, just to name a few. (AP Photo/Elaine Thompson) Joe Nicholson-USA TODAY Sports Brad Rempel-USA TODAY Sports Charles LeClaire-USA TODAY Sports Joe Nicholson-USA TODAY Sports Darren Yamashita-USA TODAY Sports Joe Nicholson-USA TODAY Sports Rich Barnes-USA TODAY Sports Joe Nicholson-USA TODAY Sports Rich Barnes-USA TODAY Sports Joe Camporeale-USA TODAY Sports Trevor Ruszkowski-USA TODAY Sports Joe Nicholson-USA TODAY Sports Darren Yamashita-USA TODAY Sports Joe Nicholson-USA TODAY Sports (AP Photo/Ted S.&#34;,&#34;rights&#34;:&#34;usatoday.com&#34;,&#34;rank&#34;:126,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Tim Weaver&#34;,&#34;October&#34;,&#34;Am Pt&#34;],&#34;media&#34;:&#34;https://seahawkswire.usatoday.com/wp-content/uploads/sites/61/2019/07/usatsi_11420506.jpg?w=1024&amp;h=576&amp;crop=1&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:null,&#34;_score&#34;:9.579414,&#34;_id&#34;:&#34;367d956086ea77886f4727640df11ac8&#34;},{&#34;title&#34;:&#34;Seahawks&#39; full list of 2022 free agents&#34;,&#34;author&#34;:&#34;Tim Weaver&#34;,&#34;published_date&#34;:&#34;2021-10-24 14:37:18&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://sports.yahoo.com/seahawks-full-list-2022-free-143718044.html&#34;,&#34;clean_url&#34;:&#34;yahoo.com&#34;,&#34;summary&#34;:&#34;The Seattle Seahawks will have some tough decisions to make this coming offseason, no matter how the rest of this year plays out. Their starting left tackle, free safety, tight end, right cornerback and No. 2 quarterback are all going to become free agents next March, just to name a few.\n\nHere is the full list of Seattle&#39;s pending 2022 free agents.\n\nFS Quandre Diggs\n\n(AP Photo/Elaine Thompson)\n\nLT Duane Brown\n\nJoe Nicholson-USA TODAY Sports\n\nCB D.J. Reed\n\nBrad Rempel-USA TODAY Sports\n\nTE Gerald E&#34;,&#34;rights&#34;:&#34;yahoo.com&#34;,&#34;rank&#34;:30,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Tim Weaver&#34;],&#34;media&#34;:&#34;https://s.yimg.com/ny/api/res/1.2/MBPMeSQbPKpYGzFX3aiNaw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/uu/api/res/1.2/3s48MSRrpdotaFM2d0QkQw--~B/aD0xNzA3O3c9MjU2MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/seattle_seahawks_wire_usa_today_sports_articles_798/e0e0589ce7fb76386e83d88a6387917b&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@Yahoo&#34;,&#34;_score&#34;:9.522131,&#34;_id&#34;:&#34;6d8e5c85fe80b1272c3a795d2b99f1bc&#34;},{&#34;title&#34;:&#34;Global Spectator Sports Market Report 2021 Featuring FC Barcelona, Dallas Cowboys, Real Madrid, Manchester United, &amp; New York Yankees&#34;,&#34;author&#34;:&#34;Research&#34;,&#34;published_date&#34;:&#34;2021-10-20 00:00:00&#34;,&#34;published_date_precision&#34;:&#34;date&#34;,&#34;link&#34;:&#34;https://www.globenewswire.com/news-release/2021/10/20/2317073/28124/en/Global-Spectator-Sports-Market-Report-2021-Featuring-FC-Barcelona-Dallas-Cowboys-Real-Madrid-Manchester-United-New-York-Yankees.html&#34;,&#34;clean_url&#34;:&#34;globenewswire.c ...

# %%
news_sp = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_sp.append(item_title)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sp = pd.DataFrame(news_sp,columns=['title','summary','link','pub_date','topic','author'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #business

# %%
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"business","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;status&#34;:&#34;ok&#34;,&#34;total_hits&#34;:10000,&#34;page&#34;:1,&#34;total_pages&#34;:400,&#34;page_size&#34;:25,&#34;articles&#34;:[{&#34;title&#34;:&#34;Writing Off the Expenses of Starting Your Own Business&#34;,&#34;author&#34;:&#34;Hannah Hottenstein&#34;,&#34;published_date&#34;:&#34;2021-10-22 20:46:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.thebalance.com/writing-off-the-expenses-of-starting-your-own-business-5206929&#34;,&#34;clean_url&#34;:&#34;thebalance.com&#34;,&#34;summary&#34;:&#34;Starting a business is no easy task, and some significant expenses can apply. Depending on your business scope, you may be able to deduct certain startup costs as business expenses from your taxes. Business expenses are costs incurred by your business to generate more revenue.\u00a0\n \nAny expense that helps your business make more money could potentially count as a business expense. This can include costs such as advertising, payroll, rent, software fees, utility fees, and more.\u00a0\n \nTo help your startup save money, you should understand how to achieve the maximum tax deductions.&#34;,&#34;rights&#34;:&#34;thebalance.com&#34;,&#34;rank&#34;:973,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;unknown&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Hannah Hottenstein&#34;,&#34;Hannah Hottenstein Is A Writer&#34;,&#34;Small Business Expert Contributing To The Balance On Topics Such As Entrepreneurship&#34;,&#34;Small Business Finance. Hannah Is Also The Founder&#34;,&#34;Proprietor Of H\u00e4nasun&#34;,&#34;A Fine Art&#34;,&#34;Antiques Business. In Addition To The Balance&#34;,&#34;Hannah Has Written For Lean Labs&#34;,&#34;Newsbreak&#34;,&#34;Several Medium Publications.&#34;],&#34;media&#34;:&#34;https://www.thebalance.com/thmb/7yL8XoyQFsxHUr2ER4rKMBm7XNE=/2119x1414/filters:fill(auto,1)/GettyImages-699337164-43d4088e7c9a45ebb651fdfd3aaf5b8f.jpg&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@thebalance&#34;,&#34;_score&#34;:6.454795,&#34;_id&#34;:&#34;2534fe22a2a10f58190c3cfb48d7cf50&#34;},{&#34;title&#34;:&#34;How To Register a Business Name&#34;,&#34;author&#34;:&#34;Paige Bennett&#34;,&#34;published_date&#34;:&#34;2021-10-19 11:00:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://blog.hubspot.com/sales/how-to-register-a-business-name&#34;,&#34;clean_url&#34;:&#34;hubspot.com&#34;,&#34;summary&#34;:&#34;Finding a business name is, well, serious business. You want something that will grow as your company does. While you can rebrand with a new name down the line, you&#39;ll save time, money, and confusion for clients by finding a business name to stick with for as long as possible.\n\nBut you can&#39;t just slap a sign on a website or building and call it a day. For legal and tax purposes, you typically have to register your business name. Unless you are a sole proprietor operating under your own name, you&#39;ll need to work with local, state, and federal agencies to register your business name.&#34;,&#34;rights&#34;:&#34;hubspot.com&#34;,&#34;rank&#34;:291,&#34;topic&#34;:&#34;business&#34;,&#34;country&#34;:&#34;unknown&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Paige Bennett&#34;],&#34;media&#34;:&#34;https://blog.hubspot.com/hubfs/Business%20Name%20%281%29.jpg#keepProtocol&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@HubSpot&#34;,&#34;_score&#34;:6.4421544,&#34;_id&#34;:&#34;bb2cc88d7bdcaca96efb2cc6d1c6f956&#34;},{&#34;title&#34;:&#34;Jay Rasik Modi Shortlisted for the 20 Most Innovative Business Leaders In 2021 by Global Business Leaders Magazine&#34;,&#34;author&#34;:&#34;Bfc Media Corp.&#34;,&#34;published_date&#34;:&#34;2021-10-25 10:01:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.prnewswire.com/news-releases/jay-rasik-modi-shortlisted-for-the-20-most-innovative-business-leaders-in-2021-by-g ...

# %%
json_string = response.text
print(json_string)
print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
print(stud_obj)
print("The type of object is: ", type(stud_obj))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;status&#34;:&#34;ok&#34;,&#34;total_hits&#34;:10000,&#34;page&#34;:1,&#34;total_pages&#34;:400,&#34;page_size&#34;:25,&#34;articles&#34;:[{&#34;title&#34;:&#34;Writing Off the Expenses of Starting Your Own Business&#34;,&#34;author&#34;:&#34;Hannah Hottenstein&#34;,&#34;published_date&#34;:&#34;2021-10-22 20:46:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.thebalance.com/writing-off-the-expenses-of-starting-your-own-business-5206929&#34;,&#34;clean_url&#34;:&#34;thebalance.com&#34;,&#34;summary&#34;:&#34;Starting a business is no easy task, and some significant expenses can apply. Depending on your business scope, you may be able to deduct certain startup costs as business expenses from your taxes. Business expenses are costs incurred by your business to generate more revenue.\u00a0\n \nAny expense that helps your business make more money could potentially count as a business expense. This can include costs such as advertising, payroll, rent, software fees, utility fees, and more.\u00a0\n \nTo help your startup save money, you should understand how to achieve the maximum tax deductions.&#34;,&#34;rights&#34;:&#34;thebalance.com&#34;,&#34;rank&#34;:973,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;unknown&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Hannah Hottenstein&#34;,&#34;Hannah Hottenstein Is A Writer&#34;,&#34;Small Business Expert Contributing To The Balance On Topics Such As Entrepreneurship&#34;,&#34;Small Business Finance. Hannah Is Also The Founder&#34;,&#34;Proprietor Of H\u00e4nasun&#34;,&#34;A Fine Art&#34;,&#34;Antiques Business. In Addition To The Balance&#34;,&#34;Hannah Has Written For Lean Labs&#34;,&#34;Newsbreak&#34;,&#34;Several Medium Publications.&#34;],&#34;media&#34;:&#34;https://www.thebalance.com/thmb/7yL8XoyQFsxHUr2ER4rKMBm7XNE=/2119x1414/filters:fill(auto,1)/GettyImages-699337164-43d4088e7c9a45ebb651fdfd3aaf5b8f.jpg&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@thebalance&#34;,&#34;_score&#34;:6.454795,&#34;_id&#34;:&#34;2534fe22a2a10f58190c3cfb48d7cf50&#34;},{&#34;title&#34;:&#34;How To Register a Business Name&#34;,&#34;author&#34;:&#34;Paige Bennett&#34;,&#34;published_date&#34;:&#34;2021-10-19 11:00:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://blog.hubspot.com/sales/how-to-register-a-business-name&#34;,&#34;clean_url&#34;:&#34;hubspot.com&#34;,&#34;summary&#34;:&#34;Finding a business name is, well, serious business. You want something that will grow as your company does. While you can rebrand with a new name down the line, you&#39;ll save time, money, and confusion for clients by finding a business name to stick with for as long as possible.\n\nBut you can&#39;t just slap a sign on a website or building and call it a day. For legal and tax purposes, you typically have to register your business name. Unless you are a sole proprietor operating under your own name, you&#39;ll need to work with local, state, and federal agencies to register your business name.&#34;,&#34;rights&#34;:&#34;hubspot.com&#34;,&#34;rank&#34;:291,&#34;topic&#34;:&#34;business&#34;,&#34;country&#34;:&#34;unknown&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Paige Bennett&#34;],&#34;media&#34;:&#34;https://blog.hubspot.com/hubfs/Business%20Name%20%281%29.jpg#keepProtocol&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@HubSpot&#34;,&#34;_score&#34;:6.4421544,&#34;_id&#34;:&#34;bb2cc88d7bdcaca96efb2cc6d1c6f956&#34;},{&#34;title&#34;:&#34;Jay Rasik Modi Shortlisted for the 20 Most Innovative Business Leaders In 2021 by Global Business Leaders Magazine&#34;,&#34;author&#34;:&#34;Bfc Media Corp.&#34;,&#34;published_date&#34;:&#34;2021-10-25 10:01:00&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.prnewswire.com/news-releases/jay-rasik-modi-shortlisted-for-the-20-most-innovative-business-leaders-in-2021-by-g ...

# %%
news_bs = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_bs.append(item_title)
  # print(item['title'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_bs = pd.DataFrame(news_bs,columns=['title','summary','link','pub_date','topic','author'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #tech

# %%
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"technology","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;status&#34;:&#34;ok&#34;,&#34;total_hits&#34;:10000,&#34;page&#34;:1,&#34;total_pages&#34;:400,&#34;page_size&#34;:25,&#34;articles&#34;:[{&#34;title&#34;:&#34;Autonomous Navigation Technology Market Size, Revenue, Demand, Major Regions, Acquisitions Landscape, Current Trends, and Forecast 2026&#34;,&#34;author&#34;:null,&#34;published_date&#34;:&#34;2021-10-20 06:30:40&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.marketwatch.com/press-release/autonomous-navigation-technology-market-size-revenue-demand-major-regions-acquisitions-landscape-current-trends-and-forecast-2026-2021-10-20&#34;,&#34;clean_url&#34;:&#34;marketwatch.com&#34;,&#34;summary&#34;:&#34;The MarketWatch News Department was not involved in the creation of this content. Oct 20, 2021 (The Expresswire) --\n\&#34;Final Report will add the analysis of the impact of COVID-19 on this industry.\&#34;Global&#39;Autonomous Navigation Technology Market&#39;presents in-depth analysis of the drivers and restraints impacting the overall market. Analysts have studied the key trends defining the trajectory of the market. The research report also includes an assessment of the achievements made by the players in the global Autonomous Navigation Technology market so far.&#34;,&#34;rights&#34;:&#34;marketwatch.com&#34;,&#34;rank&#34;:279,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[],&#34;media&#34;:&#34;https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@marketwatch&#34;,&#34;_score&#34;:7.657815,&#34;_id&#34;:&#34;49e0e05314d44a4ad69f7d0f3d13da4e&#34;},{&#34;title&#34;:&#34;The pitch deck for Trump&#39;s new media venture teases a &#39;conservative media universe&#39; meant to rival the mainstream&#34;,&#34;author&#34;:&#34;Katie Canales Francis Agustin&#34;,&#34;published_date&#34;:&#34;2021-10-21 19:42:14&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://news.yahoo.com/pitch-deck-trumps-media-venture-194214347.html&#34;,&#34;clean_url&#34;:&#34;yahoo.com&#34;,&#34;summary&#34;:&#34;Trump launched his new Twitter copycat TRUTH after being booted from mainstream social platforms for violating their policies. Trump Media &amp; Technology Group Corp.\n\nTrump is rolling out a Twitter-like social app called TRUTH.\n\nThe app is part of a larger company that aims to create a media ecosystem free of \&#34;liberal bias.\&#34;\n\nThe firm, TMTG, wants to become a \&#34;media powerhouse\&#34; to take on the streaming and news companies.\n\nFormer President Donald Trump is forging yet another attack on what he and other conservatives say is mainstream media&#39;s crusade to censor them.&#34;,&#34;rights&#34;:&#34;yahoo.com&#34;,&#34;rank&#34;:30,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Katie Canales Francis Agustin&#34;],&#34;media&#34;:&#34;https://s.yimg.com/ny/api/res/1.2/8fEpp93IBq3jYD1LKFXj5Q--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD05MDA-/https://s.yimg.com/uu/api/res/1.2/EwzNBg8yUrXMM5cFar43OQ--~B/aD0xMDczO3c9MTQzMTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/business_insider_articles_888/7e3e1aa39f14ec4176612edd687b5f5e&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@YahooNews&#34;,&#34;_score&#34;:7.631896,&#34;_id&#34;:&#34;d26957e6996a377a5fbbbe55ade1d588&#34;},{&#34;title&#34;:&#34;Global Broadcast and Media Technology Market Size to 2027&#34;,&#34;author&#34;:&#34;Industry Research&#34;,&#34;published_date&#34;:&#34;2021-10-20 12:05:44&#34;,&#34;published_date_precision&#34;:&#34;timezone unknown&#34;,&#34;link&#34;:&#34;https://www.globenewswire.com/news-release/2021/10/20/2317374/0/en/Global-Broadcast-and-Media-Technology-Market-Size-to-2027-Analysis-By-Upcoming-Trends-and-Challenges-Industry-Revenue-Growth-Factors-Future-Strategic-Planning-Key-Ve ...

# %%
json_string = response.text
print(json_string)
print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
print(stud_obj)
print("The type of object is: ", type(stud_obj))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;status&#34;:&#34;ok&#34;,&#34;total_hits&#34;:10000,&#34;page&#34;:1,&#34;total_pages&#34;:400,&#34;page_size&#34;:25,&#34;articles&#34;:[{&#34;title&#34;:&#34;Autonomous Navigation Technology Market Size, Revenue, Demand, Major Regions, Acquisitions Landscape, Current Trends, and Forecast 2026&#34;,&#34;author&#34;:null,&#34;published_date&#34;:&#34;2021-10-20 06:30:40&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://www.marketwatch.com/press-release/autonomous-navigation-technology-market-size-revenue-demand-major-regions-acquisitions-landscape-current-trends-and-forecast-2026-2021-10-20&#34;,&#34;clean_url&#34;:&#34;marketwatch.com&#34;,&#34;summary&#34;:&#34;The MarketWatch News Department was not involved in the creation of this content. Oct 20, 2021 (The Expresswire) --\n\&#34;Final Report will add the analysis of the impact of COVID-19 on this industry.\&#34;Global&#39;Autonomous Navigation Technology Market&#39;presents in-depth analysis of the drivers and restraints impacting the overall market. Analysts have studied the key trends defining the trajectory of the market. The research report also includes an assessment of the achievements made by the players in the global Autonomous Navigation Technology market so far.&#34;,&#34;rights&#34;:&#34;marketwatch.com&#34;,&#34;rank&#34;:279,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[],&#34;media&#34;:&#34;https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@marketwatch&#34;,&#34;_score&#34;:7.657815,&#34;_id&#34;:&#34;49e0e05314d44a4ad69f7d0f3d13da4e&#34;},{&#34;title&#34;:&#34;The pitch deck for Trump&#39;s new media venture teases a &#39;conservative media universe&#39; meant to rival the mainstream&#34;,&#34;author&#34;:&#34;Katie Canales Francis Agustin&#34;,&#34;published_date&#34;:&#34;2021-10-21 19:42:14&#34;,&#34;published_date_precision&#34;:&#34;full&#34;,&#34;link&#34;:&#34;https://news.yahoo.com/pitch-deck-trumps-media-venture-194214347.html&#34;,&#34;clean_url&#34;:&#34;yahoo.com&#34;,&#34;summary&#34;:&#34;Trump launched his new Twitter copycat TRUTH after being booted from mainstream social platforms for violating their policies. Trump Media &amp; Technology Group Corp.\n\nTrump is rolling out a Twitter-like social app called TRUTH.\n\nThe app is part of a larger company that aims to create a media ecosystem free of \&#34;liberal bias.\&#34;\n\nThe firm, TMTG, wants to become a \&#34;media powerhouse\&#34; to take on the streaming and news companies.\n\nFormer President Donald Trump is forging yet another attack on what he and other conservatives say is mainstream media&#39;s crusade to censor them.&#34;,&#34;rights&#34;:&#34;yahoo.com&#34;,&#34;rank&#34;:30,&#34;topic&#34;:&#34;news&#34;,&#34;country&#34;:&#34;US&#34;,&#34;language&#34;:&#34;en&#34;,&#34;authors&#34;:[&#34;Katie Canales Francis Agustin&#34;],&#34;media&#34;:&#34;https://s.yimg.com/ny/api/res/1.2/8fEpp93IBq3jYD1LKFXj5Q--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD05MDA-/https://s.yimg.com/uu/api/res/1.2/EwzNBg8yUrXMM5cFar43OQ--~B/aD0xMDczO3c9MTQzMTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/business_insider_articles_888/7e3e1aa39f14ec4176612edd687b5f5e&#34;,&#34;is_opinion&#34;:false,&#34;twitter_account&#34;:&#34;@YahooNews&#34;,&#34;_score&#34;:7.631896,&#34;_id&#34;:&#34;d26957e6996a377a5fbbbe55ade1d588&#34;},{&#34;title&#34;:&#34;Global Broadcast and Media Technology Market Size to 2027&#34;,&#34;author&#34;:&#34;Industry Research&#34;,&#34;published_date&#34;:&#34;2021-10-20 12:05:44&#34;,&#34;published_date_precision&#34;:&#34;timezone unknown&#34;,&#34;link&#34;:&#34;https://www.globenewswire.com/news-release/2021/10/20/2317374/0/en/Global-Broadcast-and-Media-Technology-Market-Size-to-2027-Analysis-By-Upcoming-Trends-and-Challenges-Industry-Revenue-Growth-Factors-Future-Strategic-Planning-Key-Ve ...

# %%
news_tech = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_tech.append(item_title)
  # print(item['title'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_tech = pd.DataFrame(news_tech,columns=['title','summary','link','pub_date','topic','author'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Merging all dataframes

# %%
df_s1 = df_bs.append(df_sp, ignore_index=True)
df_s2 = df_s1.append(df_tech, ignore_index=True)
df_s3 = df_s2.append(df_e, ignore_index=True)
df_Final = df_s3.append(df_bs, ignore_index=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_df = spark.createDataFrame(df_Final)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # LogReg CrossValidation using hyperParameters

# %%
# Start a new MLflow run
import mlflow.mleap
import mlflow.sklearn
from pyspark.ml.feature import HashingTF, IDF
from pyspark.ml import Pipeline
from pyspark.ml.feature import RegexTokenizer, StopWordsRemover, CountVectorizer
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, IDF
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

with mlflow.start_run(run_name="News_priediction_cvModel") as run:
  
# regular expression tokenizer
  regexTokenizer = RegexTokenizer(inputCol="summary", outputCol="words", pattern="\\W")
  # stop words
  add_stopwords = ["http","https","amp","rt","t","c","the"] 
  stopwordsRemover = StopWordsRemover(inputCol="words", outputCol="filtered").setStopWords(add_stopwords)
  # bag of words count
  countVectors = CountVectorizer(inputCol="filtered", outputCol="features", vocabSize=10000, minDF=5)
  label_stringIdx = StringIndexer(inputCol = "topic", outputCol = "label")

  # hashingTF = HashingTF(inputCol="filtered", outputCol="rawFeatures", numFeatures=10000)
  # idf = IDF(inputCol="rawFeatures", outputCol="features", minDocFreq=5) #minDocFreq: remove sparse terms
  pipeline = Pipeline(stages=[regexTokenizer, stopwordsRemover, countVectors, label_stringIdx])
  pipelineFit = pipeline.fit(train_df)
  dataset = pipelineFit.transform(train_df)
  (trainingData, testData) = dataset.randomSplit([0.7, 0.3], seed = 100)
  lr = LogisticRegression(maxIter=20, regParam=0.3, elasticNetParam=0)
 
  evaluator_lr_tf = MulticlassClassificationEvaluator(predictionCol="prediction")
  # Create ParamGrid for Cross Validation
  paramGrid = (ParamGridBuilder()
              .addGrid(lr.regParam, [0.1, 0.3, 0.5]) # regularization parameter
              .addGrid(lr.elasticNetParam, [0.0, 0.1, 0.2]) # Elastic Net Parameter (Ridge = 0)
  #            .addGrid(model.maxIter, [10, 20, 50]) #Number of iterations
  #            .addGrid(idf.numFeatures, [10, 100, 1000]) # Number of features
              .build())
  # Create 5-fold CrossValidator
  cv = CrossValidator(estimator=lr, \
                      estimatorParamMaps=paramGrid, \
                      evaluator=evaluator_lr_tf, \
                      numFolds=5)
  cvModel = cv.fit(trainingData)

  predictions = cvModel.transform(testData)
  # Evaluate best model
  evaluator_cv = MulticlassClassificationEvaluator(predictionCol="prediction")
  evaluator_cv.evaluate(predictions)
  runID = run.info.run_uuid
  experimentID = run.info.experiment_id

  print("Inside MLflow Run with run_id {} and experiment_id {}".format(runID, experimentID))
  # mlflow.sklearn.log_model(lrModel, "lrModel")
  # mlflow.log_params(params)
  # Training data f1 score
  evaluator_cv = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol='label', metricName='f1')
  F1 = evaluator_cv.evaluate(predictions)
  # Training data Accuracy
  evaluator_cv = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol='label', metricName='accuracy')
  acc = evaluator_cv.evaluate(predictions)
  # print some data
  print("F1_score_Training",F1)
  print("Accuracy_Training",acc)

  mlflow.spark.log_model(spark_model=cvModel, sample_input=trainingData, artifact_path="model")
  mlflow.spark.save_model(cvModel, "cvModel")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">MLlib will automatically track trials in MLflow. After your tuning fit() call has completed, view the MLflow UI to see logged runs.
# Inside MLflow Run with run_id d89ed0f030454f03b4ce434b11f5949c and experiment_id 3022426119685316
# F1_score_Training 0.6801948051948052
# Accuracy_Training 0.7272727272727273
# </div>

# %%
# import joblib
from joblib import dump

# dump the pipeline model
dump(pipeline, filename="text_classification.joblib")
