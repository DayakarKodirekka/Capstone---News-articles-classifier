# %%
# Entertainment
import requests
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"entertainment","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring, verify=False)

#print(response.text)
# Out:
# C:\Users\KSindhu\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'free-news.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
import json
# entertaiment 
json_string = response.text
# print(json_string)
# print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
# print(stud_obj)
# print("The type of object is: ", type(stud_obj))

# %%
news_et = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_et.append(item_title)

# %%
import pandas as pd
df_e = pd.DataFrame(news_et,columns=['title','summary','link','pub_date','topic','author'])
df_e['topic']='entertainment'

# %%
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"sports","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring,verify=False)

# print(response.text)
# Out:
# C:\Users\KSindhu\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'free-news.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
# sports 
json_string = response.text
# print(json_string)
# print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
# print(stud_obj)
# print("The type of object is: ", type(stud_obj))

# %%
news_sp = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_sp.append(item_title)

# %%
df_sp = pd.DataFrame(news_sp,columns=['title','summary','link','pub_date','topic','author'])
df_sp['topic']='sport'

# %%
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"business","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring,verify=False)

# print(response.text)
# Out:
# C:\Users\KSindhu\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'free-news.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
json_string = response.text
# print(json_string)
# print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
# print(stud_obj)
# print("The type of object is: ", type(stud_obj))

# %%
news_bs = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_bs.append(item_title)
  # print(item['title'])

# %%
df_bs = pd.DataFrame(news_bs,columns=['title','summary','link','pub_date','topic','author'])
df_bs['topic']='business'

# %%
url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"technology","lang":"en"}

headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': "b593c9a319msh312e606d9a8f636p1ac2a1jsn57d0059e91f6"
    }

response = requests.request("GET", url, headers=headers, params=querystring,verify=False)

#print(response.text)
# Out:
# C:\Users\KSindhu\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'free-news.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
json_string = response.text
#print(json_string)
#print("The type of object is: ", type(json_string))
stud_obj = json.loads(json_string)
#print(stud_obj)
#print("The type of object is: ", type(stud_obj))

# %%
news_tech = []
for item in stud_obj['articles']:
  item_title = {}
  item_title['title'] = item['title']
  item_title['link'] = item['link']
  item_title['topic'] = item['topic']
  item_title['pub_date'] = item['published_date']
  item_title['summary'] = item['summary']
  item_title['author'] = item['author']
  news_tech.append(item_title)
  # print(item['title'])

# %%
df_tech = pd.DataFrame(news_tech,columns=['title','summary','link','pub_date','topic','author'])
df_tech['topic']='tech'

# %%
df_s1 = df_bs.append(df_sp, ignore_index=True)
df_s2 = df_s1.append(df_tech, ignore_index=True)
df_s3 = df_s2.append(df_e, ignore_index=True)
df_Final = df_s3.append(df_bs, ignore_index=True)

# %%
df_train2 = pd.read_csv("BBC News Train.csv")
df_train2 = df_train2[['Text', 'Category']]
df_train2.columns = ['summary', 'topic']
df_train2.head(5)
# Out:
#                                              summary     topic
# 0  worldcom ex-boss launches defence lawyers defe...  business
# 1  german business confidence slides german busin...  business
# 2  bbc poll indicates economic gloom citizens in ...  business
# 3  lifestyle  governs mobile choice  faster  bett...      tech
# 4  enron bosses in $168m payout eighteen former e...  business

# %%
df_train = df_Final[['summary','topic']]
df_train = df_train.append(df_train2,ignore_index=True)

# %%
df_train['topic'].value_counts()
# Out:
# business         386
# sport            371
# entertainment    298
# tech             286
# politics         274
# Name: topic, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(df_train['summary'], df_train['topic'], random_state = 0)
#count_vect = CountVectorizer()
#X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfVectorizer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(tfidf_transformer.transform(["This company refuses to provide me verification and validation of debt per my right under the FDCPA. I do not believe this debt is mine."])))
# Out:
# ['business']

# %%
res=clf.predict(tfidf_transformer.transform(X_test))

# %%
import joblib
from joblib import dump

# dump the pipeline model
dump(tfidf_transformer, filename="transformer.joblib")
# Out:
# ['transformer.joblib']

# %%
dump(clf, filename="text_classification_nb.joblib")
# Out:
# ['text_classification_nb.joblib']

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf_rf = RandomForestClassifier().fit(X_train_tfidf, y_train)

# %%
dump(clf_rf, filename="text_classification_rf.joblib")
# Out:
# ['text_classification_rf.joblib']

# %% [markdown]
# # Logistic Regression Classifier

# %%
from sklearn.linear_model import LogisticRegression
clf_lr = LogisticRegression().fit(X_train_tfidf, y_train)

# %%
dump(clf_lr, filename="text_classification_lr.joblib")
# Out:
# ['text_classification_lr.joblib']

# %% [markdown]
# # Support vector Classifier

# %%
from sklearn.svm import LinearSVC
clf_svc = LinearSVC().fit(X_train_tfidf, y_train)

# %%
dump(clf_svc, filename="text_classification_svc.joblib")
# Out:
# ['text_classification_svc.joblib']

# %% [markdown]
# # Comparison of models

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(df_Final.summary).toarray()
labels = df_Final.topic
features.shape
# Out:
# (125, 436)

# %%
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=16, jitter=True, edgecolor="gray", linewidth=4)
plt.show()

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.936
# LogisticRegression        0.872
# MultinomialNB             0.856
# RandomForestClassifier    0.736
# Name: accuracy, dtype: float64
